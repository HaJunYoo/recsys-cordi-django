# %%
import pandas as pd

# %%
df = pd.read_csv('product.csv',index_col='Unnamed: 0')

# %%
df
# Out:
#                                  name main_category sub_category  \
# 0                         NM2DN51A_빅샷            가방           백팩
# 1                          THINK PACK            가방           백팩
# 2                        메쉬 스트링 백팩 블랙            가방           백팩
# 3                          앱솔루트 백팩 블랙            가방           백팩
# 4                        슈퍼브레이크 BLACK            가방           백팩
# ...                               ...           ...          ...
# 8740  Check Varsity Track Pants Khaki            하의   트레이닝/조거 팬츠
# 8741         우먼즈 릴렉스드 라운지 스웨트 팬츠 [크림]            하의   트레이닝/조거 팬츠
# 8742               와이드 린넨 카고 조거 팬츠 카키            하의   트레이닝/조거 팬츠
# 8743           NSW 클럽 조거팬츠 BV2680-063            하의   트레이닝/조거 팬츠
# 8744                   카고 조거 팬츠 (올리브)            하의   트레이닝/조거 팬츠
#
#                  brand        number  \
# 0       THE NORTH FACE      NM2DN51A
# 1                 YALE  YB1BG0031BK0
# 2            NEIKIDNIS    NBP005-101
# ...

# %%
df.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'brand', 'number', 'tags',
#        'price', 'rating', 'rating_num', 'season', 'gender', 'like', 'view',
#        'sale', 'coordi', 'age18', 'age19_23', 'age24_28', 'age29_33',
#        'age34_39', 'age40', 'man', 'woman', 'img', '_1', 'year', 'only_season',
#        'scaled_rating', 'review_tagged_cleaned', 'word', 'word_string',
#        'review', 'name_split'],
#       dtype='object')

# %%
del df['rating']
del df['rating_num']
del df['_1']
del df['review_tagged_cleaned']
del df['word']
del df['word_string']
del df['name_split']

# %%
df.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'brand', 'number', 'tags',
#        'price', 'season', 'gender', 'like', 'view', 'sale', 'coordi', 'age18',
#        'age19_23', 'age24_28', 'age29_33', 'age34_39', 'age40', 'man', 'woman',
#        'img', 'year', 'only_season', 'scaled_rating', 'review'],
#       dtype='object')

# %%
df.to_csv("./product2.csv")
